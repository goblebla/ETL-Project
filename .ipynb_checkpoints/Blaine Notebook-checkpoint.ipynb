# %%
import pandas as pd

# %%
race = "ShareRaceByCity.csv"
Race = pd.read_csv(race)
Race
# Out:
#       Geographic area                    City share_white share_black  \
# 0                  AL              Abanda CDP        67.2        30.2
# 1                  AL          Abbeville city        54.4        41.4
# 2                  AL         Adamsville city        52.3        44.9
# 3                  AL            Addison town        99.1         0.1
# 4                  AL              Akron town        13.2        86.5
# ...               ...                     ...         ...         ...
# 29263              WY  Woods Landing-Jelm CDP        95.9           0
# 29264              WY            Worland city        89.9         0.3
# 29265              WY             Wright town        94.5         0.1
# 29266              WY              Yoder town        97.4           0
# 29267              WY           Y-O Ranch CDP        92.8         1.5
#
#       share_native_american share_asian share_hispanic
# 0                         0           0            1.6
# 1                       0.1           1            3.1
# 2                       0.5         0.3            2.3
# 3                         0         0.1            0.4
# 4                         0           0            0.3
# ...                     ...         ...            ...
# 29263                     0         2.1              0
# 29264                   1.3         0.6           16.6
# 29265                   1.4         0.2            6.2
# 29266                     0           0              4
# 29267                   2.6           0           11.8
#
# [29268 rows x 7 columns]

# %%
poverty = "datasets_2647_4395_PercentagePeopleBelowPovertyLevel.csv"
Poverty = pd.read_csv(poverty)
Poverty
# Out:
#       Geographic Area                    City poverty_rate
# 0                  AL              Abanda CDP         78.8
# 1                  AL          Abbeville city         29.1
# 2                  AL         Adamsville city         25.5
# 3                  AL            Addison town         30.7
# 4                  AL              Akron town           42
# ...               ...                     ...          ...
# 29324              WY  Woods Landing-Jelm CDP         18.6
# 29325              WY            Worland city         15.3
# 29326              WY             Wright town          5.9
# 29327              WY              Yoder town          5.4
# 29328              WY           Y-O Ranch CDP            0
#
# [29329 rows x 3 columns]

# %%
RacePoverity = pd.merge(Race, Poverty, how="left", left_on=["City", "Geographic area"], right_on=["City", "Geographic Area"])
RacePoverity
# Out:
#       Geographic area                    City share_white share_black  \
# 0                  AL              Abanda CDP        67.2        30.2
# 1                  AL          Abbeville city        54.4        41.4
# 2                  AL         Adamsville city        52.3        44.9
# 3                  AL            Addison town        99.1         0.1
# 4                  AL              Akron town        13.2        86.5
# ...               ...                     ...         ...         ...
# 29263              WY  Woods Landing-Jelm CDP        95.9           0
# 29264              WY            Worland city        89.9         0.3
# 29265              WY             Wright town        94.5         0.1
# 29266              WY              Yoder town        97.4           0
# 29267              WY           Y-O Ranch CDP        92.8         1.5
#
#       share_native_american share_asian share_hispanic Geographic Area  \
# 0                         0           0            1.6              AL
# 1                       0.1           1            3.1              AL
# 2                       0.5         0.3            2.3              AL
# 3                         0         0.1            0.4              AL
# 4                         0           0            0.3              AL
# ...                     ...         ...            ...             ...
# 29263                     0         2.1              0              WY
# 29264                   1.3         0.6           16.6              WY
# 29265                   1.4         0.2            6.2              WY
# 29266                     0           0              4              WY
# 29267                   2.6           0           11.8              WY
#
#       poverty_rate
# 0             78.8
# 1             29.1
# 2             25.5
# 3             30.7
# 4               42
# ...            ...
# 29263         18.6
# 29264         15.3
# 29265          5.9
# 29266          5.4
# 29267            0
#
# [29268 rows x 9 columns]

# %%
new = Poverty["City"].str.replace("\scity", "")
Poverty["City"]= new
Poverty
# Out:
#       Geographic Area                    City poverty_rate
# 0                  AL              Abanda CDP         78.8
# 1                  AL               Abbeville         29.1
# 2                  AL              Adamsville         25.5
# 3                  AL            Addison town         30.7
# 4                  AL              Akron town           42
# ...               ...                     ...          ...
# 29324              WY  Woods Landing-Jelm CDP         18.6
# 29325              WY                 Worland         15.3
# 29326              WY             Wright town          5.9
# 29327              WY              Yoder town          5.4
# 29328              WY           Y-O Ranch CDP            0
#
# [29329 rows x 3 columns]

# %%
DataSet1 = "datasets_2647_4395_PoliceKillingsUS.csv"
DataSet1 = pd.read_csv(DataSet1)
Renamed = DataSet1.rename(columns={"city":"City","state":"State"})
Renamed.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           City State  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
Renamed.describe()
# Out:
#                 id          age
# count  2535.000000  2458.000000
# mean   1445.731755    36.605370
# std     794.259490    13.030774
# min       3.000000     6.000000
# 25%     768.500000    26.000000
# 50%    1453.000000    34.000000
# 75%    2126.500000    45.000000
# max    2822.000000    91.000000

# %%
DataSet2 = "police_killings_new.csv"
DataSet2 = pd.read_csv(DataSet2)
DataSet2
# Out:
#                 Victim's name Victim's age Victim's gender Victim's race  \
# 0              Eric M. Tellez           28            Male         White
# 1     Name withheld by police          NaN            Male  Unknown race
# 2                Terry Hudson           57            Male         Black
# 3              Malik Williams           23            Male         Black
# 4           Frederick Perkins           37            Male         Black
# ...                       ...          ...             ...           ...
# 7902                      NaN          NaN             NaN           NaN
# 7903                      NaN          NaN             NaN           NaN
# 7904                      NaN          NaN             NaN           NaN
# 7905                      NaN          NaN             NaN           NaN
# 7906                      NaN          NaN             NaN           NaN
#
#                                  URL of image of victim  \
# 0     https://fatalencounters.org/wp-content/uploads...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7902                                                NaN
# 7903                                                NaN
# 7904                                                NaN
# 7905                                                NaN
# 7906                                                NaN
#
#      Date of Incident (month/day/year) Street Address of Incident  \
# 0                           31/12/2019                 Broad St.
# 1                           31/12/2019             7239-7411 I-40
# 2                           31/12/2019             3600 N 24th St
# 3                           31/12/2019    30800 14th Avenue South
# 4                           31/12/2019        17057 N Outer 40 Rd
# ...                                ...                        ...
# 7902                               NaN                        NaN
# 7903                               NaN                        NaN
# 7904                               NaN                        NaN
# 7905                               NaN                        NaN
# 7906                               NaN                        NaN
#
#               City State  Zipcode  ... Unnamed: 56 Unnamed: 57 Unnamed: 58  \
# 0            Globe    AZ  85501.0  ...         NaN         NaN         NaN
# 1          Memphis    AR  38103.0  ...         NaN         NaN         NaN
# 2            Omaha    NE  68110.0  ...         NaN         NaN         NaN
# 3      Federal Way    WA  98003.0  ...         NaN         NaN         NaN
# 4     Chesterfield    MO  63005.0  ...         NaN         NaN         NaN
# ...            ...   ...      ...  ...         ...         ...         ...
# 7902           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7903           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7904           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7905           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7906           NaN   NaN      NaN  ...         NaN         NaN         NaN
#
#      Unnamed: 59 Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 7902         NaN         NaN         NaN         NaN         NaN         NaN
# 7903         NaN         NaN         NaN         NaN         NaN         NaN
# 7904         NaN         NaN         NaN         NaN         NaN         NaN
# 7905         NaN         NaN         NaN         NaN         NaN         NaN
# 7906         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 65
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7902         NaN
# 7903         NaN
# 7904         NaN
# 7905         NaN
# 7906         NaN
#
# [7907 rows x 66 columns]

# %%
CombinedDataSet = pd.merge(DataSet2, Renamed, how="left", left_on=["City", "State"], right_on=["City", "State"])
CombinedDataSet
# Out:
#                  Victim's name Victim's age Victim's gender Victim's race  \
# 0               Eric M. Tellez           28            Male         White
# 1      Name withheld by police          NaN            Male  Unknown race
# 2                 Terry Hudson           57            Male         Black
# 3                 Terry Hudson           57            Male         Black
# 4                 Terry Hudson           57            Male         Black
# ...                        ...          ...             ...           ...
# 37428                      NaN          NaN             NaN           NaN
# 37429                      NaN          NaN             NaN           NaN
# 37430                      NaN          NaN             NaN           NaN
# 37431                      NaN          NaN             NaN           NaN
# 37432                      NaN          NaN             NaN           NaN
#
#                                   URL of image of victim  \
# 0      https://fatalencounters.org/wp-content/uploads...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 37428                                                NaN
# 37429                                                NaN
# 37430                                                NaN
# 37431                                                NaN
# 37432                                                NaN
#
#       Date of Incident (month/day/year) Street Address of Incident     City  \
# 0                            31/12/2019                 Broad St.     Globe
# 1                            31/12/2019             7239-7411 I-40  Memphis
# 2                            31/12/2019             3600 N 24th St    Omaha
# 3                            31/12/2019             3600 N 24th St    Omaha
# 4                            31/12/2019             3600 N 24th St    Omaha
# ...                                 ...                        ...      ...
# 37428                               NaN                        NaN      NaN
# 37429                               NaN                        NaN      NaN
# 37430                               NaN                        NaN      NaN
# 37431                               NaN                        NaN      NaN
# 37432                               NaN                        NaN      NaN
#
#       State  Zipcode  ...      date   manner_of_death    armed   age gender  \
# 0        AZ  85501.0  ...       NaN               NaN      NaN   NaN    NaN
# 1        AR  38103.0  ...       NaN               NaN      NaN   NaN    NaN
# 2        NE  68110.0  ...  27/01/15              shot    knife  39.0      F
# 3        NE  68110.0  ...  23/02/15  shot and Tasered  unarmed  39.0      M
# 4        NE  68110.0  ...  20/05/15              shot      gun  26.0      M
# ...     ...      ...  ...       ...               ...      ...   ...    ...
# 37428   NaN      NaN  ...       NaN               NaN      NaN   NaN    NaN
# 37429   NaN      NaN  ...       NaN               NaN      NaN   NaN    NaN
# 37430   NaN      NaN  ...       NaN               NaN      NaN   NaN    NaN
# 37431   NaN      NaN  ...       NaN               NaN      NaN   NaN    NaN
# 37432   NaN      NaN  ...       NaN               NaN      NaN   NaN    NaN
#
#       race signs_of_mental_illness threat_level         flee body_camera
# 0      NaN                     NaN          NaN          NaN         NaN
# 1      NaN                     NaN          NaN          NaN         NaN
# 2        W                    True       attack  Not fleeing       False
# 3        W                   False        other  Not fleeing       False
# 4        B                   False       attack  Not fleeing       False
# ...    ...                     ...          ...          ...         ...
# 37428  NaN                     NaN          NaN          NaN         NaN
# 37429  NaN                     NaN          NaN          NaN         NaN
# 37430  NaN                     NaN          NaN          NaN         NaN
# 37431  NaN                     NaN          NaN          NaN         NaN
# 37432  NaN                     NaN          NaN          NaN         NaN
#
# [37433 rows x 78 columns]
