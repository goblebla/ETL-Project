# %%
import pandas as pd
import numpy as np

# %%
DataSet1 = "datasets_2647_4395_PoliceKillingsUS.csv"
DataSet1 = pd.read_csv(DataSet1)

#Rename all DataSet1 columns to match Dataset2
Renamed_DataSet1 = DataSet1.rename(columns={"city":"City","state":"State","name":"Victim's name",
                                   "age":"Victim's age", "gender":"Victim's gender","race":"Victim's race", "signs_of_mental_illness":"Symptoms of mental illness?","armed":"Unarmed", "manner_of_death": "Cause of death", "threat_level": "Alleged Threat Level (Source: WaPo)", "flee": "Fleeing (Source: WaPo)","body_camera": "Body Camera (Source: WaPo)", "date":"Date of Incident (month/day/year)"})
Renamed_DataSet1
# Out:
#         id       Victim's name Date of Incident (month/day/year)  \
# 0        3          Tim Elliot                          02/01/15
# 1        4    Lewis Lee Lembke                          02/01/15
# 2        5  John Paul Quintero                          03/01/15
# 3        8     Matthew Hoffman                          04/01/15
# 4        9   Michael Rodriguez                          04/01/15
# ...    ...                 ...                               ...
# 2530  2822    Rodney E. Jacobs                          28/07/17
# 2531  2813               TK TK                          28/07/17
# 2532  2818  Dennis W. Robinson                          29/07/17
# 2533  2817       Isaiah Tucker                          31/07/17
# 2534  2815        Dwayne Jeune                          31/07/17
#
#         Cause of death     Unarmed  Victim's age Victim's gender  \
# 0                 shot         gun          53.0               M
# 1                 shot         gun          47.0               M
# 2     shot and Tasered     unarmed          23.0               M
# 3                 shot  toy weapon          32.0               M
# 4                 shot    nail gun          39.0               M
# ...                ...         ...           ...             ...
# 2530              shot         gun          31.0               M
# 2531              shot     vehicle           NaN               M
# 2532              shot         gun          48.0               M
# 2533              shot     vehicle          28.0               M
# 2534              shot       knife          32.0               M
#
#      Victim's race           City State  Symptoms of mental illness?  \
# 0                A        Shelton    WA                         True
# 1                W          Aloha    OR                        False
# 2                H        Wichita    KS                        False
# 3                W  San Francisco    CA                         True
# 4                H          Evans    CO                        False
# ...            ...            ...   ...                          ...
# 2530           NaN    Kansas City    MO                        False
# 2531           NaN    Albuquerque    NM                        False
# 2532           NaN          Melba    ID                        False
# 2533             B        Oshkosh    WI                        False
# 2534             B       Brooklyn    NY                         True
#
#      Alleged Threat Level (Source: WaPo) Fleeing (Source: WaPo)  \
# 0                                 attack            Not fleeing
# 1                                 attack            Not fleeing
# 2                                  other            Not fleeing
# 3                                 attack            Not fleeing
# 4                                 attack            Not fleeing
# ...                                  ...                    ...
# 2530                              attack            Not fleeing
# 2531                              attack                    Car
# 2532                              attack                    Car
# 2533                              attack                    Car
# 2534                              attack            Not fleeing
#
#       Body Camera (Source: WaPo)
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 2530                       False
# 2531                       False
# 2532                       False
# 2533                        True
# 2534                       False
#
# [2535 rows x 14 columns]

# %%
Renamed_DataSet1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
# id                                     2535 non-null int64
# Victim's name                          2535 non-null object
# Date of Incident (month/day/year)      2535 non-null object
# Cause of death                         2535 non-null object
# Unarmed                                2526 non-null object
# Victim's age                           2458 non-null float64
# Victim's gender                        2535 non-null object
# Victim's race                          2340 non-null object
# City                                   2535 non-null object
# State                                  2535 non-null object
# Symptoms of mental illness?            2535 non-null bool
# Alleged Threat Level (Source: WaPo)    2535 non-null object
# Fleeing (Source: WaPo)                 2470 non-null object
# Body Camera (Source: WaPo)             2535 non-null bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 242.7+ KB

# %%
#Read in Dataset2
DataSet2 = "police_killings_new.csv"
DataSet2 = pd.read_csv(DataSet2)
DataSet2
# Out:
#                 Victim's name Victim's age Victim's gender Victim's race  \
# 0              Eric M. Tellez           28            Male         White
# 1     Name withheld by police          NaN            Male  Unknown race
# 2                Terry Hudson           57            Male         Black
# 3              Malik Williams           23            Male         Black
# 4           Frederick Perkins           37            Male         Black
# ...                       ...          ...             ...           ...
# 7902                      NaN          NaN             NaN           NaN
# 7903                      NaN          NaN             NaN           NaN
# 7904                      NaN          NaN             NaN           NaN
# 7905                      NaN          NaN             NaN           NaN
# 7906                      NaN          NaN             NaN           NaN
#
#                                  URL of image of victim  \
# 0     https://fatalencounters.org/wp-content/uploads...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7902                                                NaN
# 7903                                                NaN
# 7904                                                NaN
# 7905                                                NaN
# 7906                                                NaN
#
#      Date of Incident (month/day/year) Street Address of Incident  \
# 0                           31/12/2019                 Broad St.
# 1                           31/12/2019             7239-7411 I-40
# 2                           31/12/2019             3600 N 24th St
# 3                           31/12/2019    30800 14th Avenue South
# 4                           31/12/2019        17057 N Outer 40 Rd
# ...                                ...                        ...
# 7902                               NaN                        NaN
# 7903                               NaN                        NaN
# 7904                               NaN                        NaN
# 7905                               NaN                        NaN
# 7906                               NaN                        NaN
#
#               City State  Zipcode  ... Unnamed: 56 Unnamed: 57 Unnamed: 58  \
# 0            Globe    AZ  85501.0  ...         NaN         NaN         NaN
# 1          Memphis    AR  38103.0  ...         NaN         NaN         NaN
# 2            Omaha    NE  68110.0  ...         NaN         NaN         NaN
# 3      Federal Way    WA  98003.0  ...         NaN         NaN         NaN
# 4     Chesterfield    MO  63005.0  ...         NaN         NaN         NaN
# ...            ...   ...      ...  ...         ...         ...         ...
# 7902           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7903           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7904           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7905           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7906           NaN   NaN      NaN  ...         NaN         NaN         NaN
#
#      Unnamed: 59 Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 7902         NaN         NaN         NaN         NaN         NaN         NaN
# 7903         NaN         NaN         NaN         NaN         NaN         NaN
# 7904         NaN         NaN         NaN         NaN         NaN         NaN
# 7905         NaN         NaN         NaN         NaN         NaN         NaN
# 7906         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 65
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7902         NaN
# 7903         NaN
# 7904         NaN
# 7905         NaN
# 7906         NaN
#
# [7907 rows x 66 columns]

# %%
DataSet2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7907 entries, 0 to 7906
# Data columns (total 66 columns):
# Victim's name                                                                                                                                                                 7663 non-null object
# Victim's age                                                                                                                                                                  7596 non-null object
# Victim's gender                                                                                                                                                               7655 non-null object
# Victim's race                                                                                                                                                                 7663 non-null object
# URL of image of victim                                                                                                                                                        4200 non-null object
# Date of Incident (month/day/year)                                                                                                                                             7663 non-null object
# Street Address of Incident                                                                                                                                                    7580 non-null object
# City                                                                                                                                                                          7657 non-null object
# State                                                                                                                                                                         7663 non-null object
# Zipcode                                                                                                                                                                       7624 non-null float64
# County                                                                                                                                                                        7648 non-null object
# Agency responsible for death                                                                                                                                                  7647 non-null object
# Cause of death                                                                                                                                                                7663 non-null object
# A brief description of the circumstances surrounding the death                                                                                                                7643 non-null object
# Official disposition of death (justified or other)                                                                                                                            7407 non-null object
# Criminal Charges?                                                                                                                                                             7663 non-null object
# Link to news article or photo of official document                                                                                                                            7651 non-null object
# Symptoms of mental illness?                                                                                                                                                   7652 non-null object
# Unarmed                                                                                                                                                                       7663 non-null object
# Alleged Weapon (Source: WaPo)                                                                                                                                                 7663 non-null object
# Alleged Threat Level (Source: WaPo)                                                                                                                                           5281 non-null object
# Fleeing (Source: WaPo)                                                                                                                                                        5047 non-null object
# Body Camera (Source: WaPo)                                                                                                                                                    4794 non-null object
# WaPo ID (If included in WaPo database)                                                                                                                                        4878 non-null float64
# Off-Duty Killing?                                                                                                                                                             226 non-null object
# Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )    7596 non-null object
# ID                                                                                                                                                                            7663 non-null float64
# Unnamed: 27                                                                                                                                                                   0 non-null float64
# Unnamed: 28                                                                                                                                                                   0 non-null float64
# Unnamed: 29                                                                                                                                                                   0 non-null float64
# Unnamed: 30                                                                                                                                                                   0 non-null float64
# Unnamed: 31                                                                                                                                                                   0 non-null float64
# Unnamed: 32                                                                                                                                                                   0 non-null float64
# Unnamed: 33                                                                                                                                                                   0 non-null float64
# Unnamed: 34                                                                                                                                                                   0 non-null float64
# Unnamed: 35                                                                                                                                                                   0 non-null float64
# Unnamed: 36                                                                                                                                                                   0 non-null float64
# Unnamed: 37                                                                                                                                                                   0 non-null float64
# Unnamed: 38                                                                                                                                                                   0 non-null float64
# Unnamed: 39                                                                                                                                                                   0 non-null float64
# Unnamed: 40                                                                                                                                                                   0 non-null float64
# Unnamed: 41                                                                                                                                                                   0 non-null float64
# Unnamed: 42                                                                                                                                                                   0 non-null float64
# Unnamed: 43                                                                                                                                                                   0 non-null float64
# Unnamed: 44                                                                                                                                                                   0 non-null float64
# Unnamed: 45                                                                                                                                                                   0 non-null float64
# Unnamed: 46                                                                                                                                                                   0 non-null float64
# Unnamed: 47                                                                                                                                                                   0 non-null float64
# Unnamed: 48                                                                                                                                                                   0 non-null float64
# Unnamed: 49                                                                                                                                                                   0 non-null float64
# Unnamed: 50                                                                                                                                                                   0 non-null float64
# Unnamed: 51                                                                                                                                                                   0 non-null float64
# Unnamed: 52                                                                                                                                                                   0 non-null float64
# Unnamed: 53                                                                                                                                                                   0 non-null float64
# Unnamed: 54                                                                                                                                                                   0 non-null float64
# Unnamed: 55                                                                                                                                                                   0 non-null float64
# Unnamed: 56                                                                                                                                                                   0 non-null float64
# Unnamed: 57                                                                                                                                                                   0 non-null float64
# Unnamed: 58                                                                                                                                                                   0 non-null float64
# Unnamed: 59                                                                                                                                                                   0 non-null float64
# Unnamed: 60                                                                                                                                                                   0 non-null float64
# Unnamed: 61                                                                                                                                                                   0 non-null float64
# Unnamed: 62                                                                                                                                                                   0 non-null float64
# Unnamed: 63                                                                                                                                                                   0 non-null float64
# Unnamed: 64                                                                                                                                                                   0 non-null float64
# Unnamed: 65                                                                                                                                                                   0 non-null float64
# dtypes: float64(42), object(24)
# memory usage: 4.0+ MB

# %%
#Change "Unknown" age to NaN
DataSet2.loc[DataSet2["Victim's age"]=="Unknown", "Victim's age"] = np.nan

# %%
#Change "40s" age to 40
DataSet2.loc[DataSet2["Victim's age"]=="40s", "Victim's age"] = 40

# %%
#Transfor data type to float to match DataSet1 data type
DataSet2["Victim's age"]=DataSet2["Victim's age"].astype(float)

# %%
#Concatenate the 2 Datasets
concat_df = pd.concat([Renamed_DataSet1, DataSet2 ], sort=False)
concat_df
# Out:
#        id       Victim's name Date of Incident (month/day/year)  \
# 0     3.0          Tim Elliot                          02/01/15
# 1     4.0    Lewis Lee Lembke                          02/01/15
# 2     5.0  John Paul Quintero                          03/01/15
# 3     8.0     Matthew Hoffman                          04/01/15
# 4     9.0   Michael Rodriguez                          04/01/15
# ...   ...                 ...                               ...
# 7902  NaN                 NaN                               NaN
# 7903  NaN                 NaN                               NaN
# 7904  NaN                 NaN                               NaN
# 7905  NaN                 NaN                               NaN
# 7906  NaN                 NaN                               NaN
#
#         Cause of death     Unarmed  Victim's age Victim's gender  \
# 0                 shot         gun          53.0               M
# 1                 shot         gun          47.0               M
# 2     shot and Tasered     unarmed          23.0               M
# 3                 shot  toy weapon          32.0               M
# 4                 shot    nail gun          39.0               M
# ...                ...         ...           ...             ...
# 7902               NaN         NaN           NaN             NaN
# 7903               NaN         NaN           NaN             NaN
# 7904               NaN         NaN           NaN             NaN
# 7905               NaN         NaN           NaN             NaN
# 7906               NaN         NaN           NaN             NaN
#
#      Victim's race           City State  ... Unnamed: 56 Unnamed: 57  \
# 0                A        Shelton    WA  ...         NaN         NaN
# 1                W          Aloha    OR  ...         NaN         NaN
# 2                H        Wichita    KS  ...         NaN         NaN
# 3                W  San Francisco    CA  ...         NaN         NaN
# 4                H          Evans    CO  ...         NaN         NaN
# ...            ...            ...   ...  ...         ...         ...
# 7902           NaN            NaN   NaN  ...         NaN         NaN
# 7903           NaN            NaN   NaN  ...         NaN         NaN
# 7904           NaN            NaN   NaN  ...         NaN         NaN
# 7905           NaN            NaN   NaN  ...         NaN         NaN
# 7906           NaN            NaN   NaN  ...         NaN         NaN
#
#      Unnamed: 58 Unnamed: 59 Unnamed: 60 Unnamed: 61  Unnamed: 62 Unnamed: 63  \
# 0            NaN         NaN         NaN         NaN          NaN         NaN
# 1            NaN         NaN         NaN         NaN          NaN         NaN
# 2            NaN         NaN         NaN         NaN          NaN         NaN
# 3            NaN         NaN         NaN         NaN          NaN         NaN
# 4            NaN         NaN         NaN         NaN          NaN         NaN
# ...          ...         ...         ...         ...          ...         ...
# 7902         NaN         NaN         NaN         NaN          NaN         NaN
# 7903         NaN         NaN         NaN         NaN          NaN         NaN
# 7904         NaN         NaN         NaN         NaN          NaN         NaN
# 7905         NaN         NaN         NaN         NaN          NaN         NaN
# 7906         NaN         NaN         NaN         NaN          NaN         NaN
#
#      Unnamed: 64 Unnamed: 65
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 7902         NaN         NaN
# 7903         NaN         NaN
# 7904         NaN         NaN
# 7905         NaN         NaN
# 7906         NaN         NaN
#
# [10442 rows x 67 columns]

# %%
#Drop strange colums at the end of Df
concat_df = concat_df.drop(columns=concat_df.columns[29:])

# %%
#check columns and data types
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10442 entries, 0 to 7906
# Data columns (total 29 columns):
# id                                                                                                                                                                            2535 non-null float64
# Victim's name                                                                                                                                                                 10198 non-null object
# Date of Incident (month/day/year)                                                                                                                                             10198 non-null object
# Cause of death                                                                                                                                                                10198 non-null object
# Unarmed                                                                                                                                                                       10189 non-null object
# Victim's age                                                                                                                                                                  9916 non-null float64
# Victim's gender                                                                                                                                                               10190 non-null object
# Victim's race                                                                                                                                                                 10003 non-null object
# City                                                                                                                                                                          10192 non-null object
# State                                                                                                                                                                         10198 non-null object
# Symptoms of mental illness?                                                                                                                                                   10187 non-null object
# Alleged Threat Level (Source: WaPo)                                                                                                                                           7816 non-null object
# Fleeing (Source: WaPo)                                                                                                                                                        7517 non-null object
# Body Camera (Source: WaPo)                                                                                                                                                    7329 non-null object
# URL of image of victim                                                                                                                                                        4200 non-null object
# Street Address of Incident                                                                                                                                                    7580 non-null object
# Zipcode                                                                                                                                                                       7624 non-null float64
# County                                                                                                                                                                        7648 non-null object
# Agency responsible for death                                                                                                                                                  7647 non-null object
# A brief description of the circumstances surrounding the death                                                                                                                7643 non-null object
# Official disposition of death (justified or other)                                                                                                                            7407 non-null object
# Criminal Charges?                                                                                                                                                             7663 non-null object
# Link to news article or photo of official document                                                                                                                            7651 non-null object
# Alleged Weapon (Source: WaPo)                                                                                                                                                 7663 non-null object
# WaPo ID (If included in WaPo database)                                                                                                                                        4878 non-null float64
# Off-Duty Killing?                                                                                                                                                             226 non-null object
# Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )    7596 non-null object
# ID                                                                                                                                                                            7663 non-null float64
# Unnamed: 27                                                                                                                                                                   0 non-null float64
# dtypes: float64(6), object(23)
# memory usage: 2.4+ MB

# %%
#Drop unused columns
concat_df = concat_df.drop(columns=["WaPo ID (If included in WaPo database)", "URL of image of victim", "Off-Duty Killing?","Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )", "Link to news article or photo of official document" ])

# %%
#Remove duplicates based on Name, City, and State
concat_df = concat_df.drop_duplicates(subset = ["Victim's name","City", "State"])

# %%
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8659 entries, 0 to 7663
# Data columns (total 24 columns):
# id                                                                2530 non-null float64
# Victim's name                                                     8658 non-null object
# Date of Incident (month/day/year)                                 8658 non-null object
# Cause of death                                                    8658 non-null object
# Unarmed                                                           8649 non-null object
# Victim's age                                                      8423 non-null float64
# Victim's gender                                                   8651 non-null object
# Victim's race                                                     8467 non-null object
# City                                                              8652 non-null object
# State                                                             8658 non-null object
# Symptoms of mental illness?                                       8647 non-null object
# Alleged Threat Level (Source: WaPo)                               6312 non-null object
# Fleeing (Source: WaPo)                                            6028 non-null object
# Body Camera (Source: WaPo)                                        5833 non-null object
# Street Address of Incident                                        6057 non-null object
# Zipcode                                                           6093 non-null float64
# County                                                            6114 non-null object
# Agency responsible for death                                      6112 non-null object
# A brief description of the circumstances surrounding the death    6109 non-null object
# Official disposition of death (justified or other)                5954 non-null object
# Criminal Charges?                                                 6128 non-null object
# Alleged Weapon (Source: WaPo)                                     6128 non-null object
# ID                                                                6128 non-null float64
# Unnamed: 27                                                       0 non-null float64
# dtypes: float64(5), object(19)
# memory usage: 1.7+ MB

# %%
#Rename final columns for consistency to enter in DB
New_df = concat_df.rename(columns={"id":"ID", "Victim's name": "Name", "Victim's age": "Age", "Cause of death": "Death_cause", "Unarmed": "Armed", "Victim's gender": "Gender", "Victim's race": "Race", "Symptoms of mental illness?": "Mental_illness", "Alleged Threat Level (Source: WaPo)": "Threat_level", "Fleeing (Source: WaPo)": "Fleeing", "Body Camera (Source: WaPo)": "Body_camera", "Date of Incident (month/day/year)": "Date", "Street Address of Incident": "Address", "Agency responsible for death": "Agency", "A brief description of the circumstances surrounding the death": "Description", "Official disposition of death (justified or other)": "Disposition_of_death", "Criminal Charges?": "Criminal_charges", "Alleged Weapon (Source: WaPo)": "Alleged_weapon"})

# %%
#Check new column names
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8659 entries, 0 to 7663
# Data columns (total 24 columns):
# ID                      2530 non-null float64
# Name                    8658 non-null object
# Date                    8658 non-null object
# Death_cause             8658 non-null object
# Armed                   8649 non-null object
# Age                     8423 non-null float64
# Gender                  8651 non-null object
# Race                    8467 non-null object
# City                    8652 non-null object
# State                   8658 non-null object
# Mental_illness          8647 non-null object
# Threat_level            6312 non-null object
# Fleeing                 6028 non-null object
# Body_camera             5833 non-null object
# Address                 6057 non-null object
# Zipcode                 6093 non-null float64
# County                  6114 non-null object
# Agency                  6112 non-null object
# Description             6109 non-null object
# Disposition_of_death    5954 non-null object
# Criminal_charges        6128 non-null object
# Alleged_weapon          6128 non-null object
# ID                      6128 non-null float64
# Unnamed: 27             0 non-null float64
# dtypes: float64(5), object(19)
# memory usage: 1.7+ MB

# %%
#Normalize the data en columns. Homogeneous data

# %%
#Cleanup Mental Illness column
New_df["Mental_illness"].value_counts()
# Out:
# No                     3921
# False                  1898
# Yes                    1097
# Unknown                 849
# True                    632
# Drug or alcohol use     248
# unknown                   1
# Unknown                   1
# Name: Mental_illness, dtype: int64

# %%
#Change "True" values to "Yes" for normalization, etc
New_df.loc[New_df["Mental_illness"]==True, "Mental_illness"] = "Yes"

# %%
New_df.loc[New_df["Mental_illness"]==False, "Mental_illness"] = "No"

# %%
New_df.loc[New_df["Mental_illness"]=="unknown", "Mental_illness"] = "Unknown"

# %%
New_df.loc[New_df["Mental_illness"]=="Unknown ", "Mental_illness"] = "Unknown"

# %%
#Cleanup Fleeing column
New_df["Fleeing"].value_counts()
# Out:
# Not fleeing    4033
# Car             976
# Foot            743
# Other           178
# 0                83
# not fleeing       8
# car               5
# foot              2
# Name: Fleeing, dtype: int64

# %%
New_df.loc[New_df["Fleeing"]=="car", "Fleeing"] = "Car"

# %%
New_df.loc[New_df["Fleeing"]=="foot", "Fleeing"] = "Foot"

# %%
New_df.loc[New_df["Fleeing"]=="0", "Fleeing"] = "Other"

# %%
New_df.loc[New_df["Fleeing"]=="not fleeing", "Fleeing"] = "Not fleeing"

# %%
#Clean up Threat Level column. Looks good
New_df["Threat_level"].value_counts()
# Out:
# attack          4044
# other           1889
# undetermined     379
# Name: Threat_level, dtype: int64

# %%
#Armed -- How to proceed? It has too many categories
New_df["Armed"].value_counts()
# Out:
# Allegedly Armed            4273
# gun                        1393
# Unarmed                     896
# Unclear                     548
# Vehicle                     411
#                            ...
# cordless drill                1
# chain                         1
# oar                           1
# glass shard                   1
# baseball bat and bottle       1
# Name: Armed, Length: 72, dtype: int64

# %%
New_df["Age"].value_counts()
# Out:
# 25.0    286
# 34.0    277
# 31.0    270
# 32.0    269
# 27.0    268
#        ...
# 10.0      1
# 7.0       1
# 79.0      1
# 93.0      1
# 95.0      1
# Name: Age, Length: 85, dtype: int64

# %%
New_df["Race"].value_counts()
# Out:
# White               2700
# Black               1539
# W                   1201
# Hispanic            1012
# Unknown race         629
# B                    617
# H                    423
# Native American       85
# Asian                 80
# Unknown Race          47
# A                     39
# Pacific Islander      36
# N                     31
# O                     28
# Name: Race, dtype: int64

# %%
New_df.loc[New_df["Race"]=="W", "Race"] = "White"

# %%
New_df.loc[New_df["Race"]=="B", "Race"] = "Black"

# %%
New_df.loc[New_df["Race"]=="H", "Race"] = "Hispanic"

# %%
New_df.loc[New_df["Race"]=="A", "Race"] = "Asian"

# %%
New_df.loc[New_df["Race"]=="N", "Race"] = "Native American"

# %%
New_df.loc[New_df["Race"]=="O", "Race"] = "Unknown race"

# %%
New_df.loc[New_df["Race"]=="Unknown Race", "Race"] = "Unknown race"

# %%
New_df["Gender"].value_counts()
# Out:
# Male           5783
# M              2423
# Female          328
# F               107
# Transgender       7
# Unknown           3
# Name: Gender, dtype: int64

# %%
New_df.loc[New_df["Gender"]=="M", "Gender"] = "Male"

# %%
New_df.loc[New_df["Gender"]=="F", "Gender"] = "Female"

# %%
New_df = concat_df.drop(columns=["Unnamed: 27", "id", "ID"])

# %%
New_df
#how to manage the NaNs?
# Out:
#             Victim's name Date of Incident (month/day/year)    Cause of death  \
# 0              Tim Elliot                          02/01/15              shot
# 1        Lewis Lee Lembke                          02/01/15              shot
# 2      John Paul Quintero                          03/01/15  shot and Tasered
# 3         Matthew Hoffman                          04/01/15              shot
# 4       Michael Rodriguez                          04/01/15              shot
# ...                   ...                               ...               ...
# 7659           Tyree Bell                        01/01/2013           Gunshot
# 7660  Christopher Tavares                        01/01/2013           Gunshot
# 7661    Andrew L. Closson                        01/01/2013           Gunshot
# 7662        Andrew Layton                        01/01/2013             Taser
# 7663                  NaN                               NaN               NaN
#
#               Unarmed  Victim's age Victim's gender Victim's race  \
# 0                 gun          53.0               M             A
# 1                 gun          47.0               M             W
# 2             unarmed          23.0               M             H
# 3          toy weapon          32.0               M             W
# 4            nail gun          39.0               M             H
# ...               ...           ...             ...           ...
# 7659  Allegedly Armed          31.0            Male         Black
# 7660  Allegedly Armed          21.0            Male      Hispanic
# 7661  Allegedly Armed          21.0            Male         White
# 7662          Unarmed          26.0            Male         White
# 7663              NaN           NaN             NaN           NaN
#
#                City State Symptoms of mental illness?  ...  \
# 0           Shelton    WA                        True  ...
# 1             Aloha    OR                       False  ...
# 2           Wichita    KS                       False  ...
# 3     San Francisco    CA                        True  ...
# 4             Evans    CO                       False  ...
# ...             ...   ...                         ...  ...
# 7659          Omaha    NE                         Yes  ...
# 7660         Pueblo    CO                          No  ...
# 7661         Gordon    WI         Drug or alcohol use  ...
# 7662        Mankato    MN                          No  ...
# 7663            NaN   NaN                         NaN  ...
#
#      Fleeing (Source: WaPo) Body Camera (Source: WaPo)  \
# 0               Not fleeing                      False
# 1               Not fleeing                      False
# 2               Not fleeing                      False
# 3               Not fleeing                      False
# 4               Not fleeing                      False
# ...                     ...                        ...
# 7659                    NaN                        NaN
# 7660                    NaN                        NaN
# 7661                    NaN                        NaN
# 7662                    NaN                        NaN
# 7663                    NaN                        NaN
#
#                  Street Address of Incident  Zipcode      County  \
# 0                                       NaN      NaN         NaN
# 1                                       NaN      NaN         NaN
# 2                                       NaN      NaN         NaN
# 3                                       NaN      NaN         NaN
# 4                                       NaN      NaN         NaN
# ...                                     ...      ...         ...
# 7659                       3727 N. 42nd St.  68111.0     Douglas
# 7660  Highway 50 and North Elizabeth Street  81008.0      Pueblo
# 7661                        U.S. Highway 53  54838.0     Douglas
# 7662                 410 S Riverfront Drive  56001.0  Blue Earth
# 7663                                    NaN      NaN         NaN
#
#              Agency responsible for death  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 7659              Omaha Police Department
# 7660             Pueblo Police Department
# 7661      Douglas County Sheriff's Office
# 7662  Mankato Department of Public Safety
# 7663                                  NaN
#
#      A brief description of the circumstances surrounding the death  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7659  Omaha Police Department responded to a 911 dom...
# 7660  Christopher was with two others in a car. Pueb...
# 7661  Deputies responded to a 911 call of shots fire...
# 7662  Former combat medic Layton was found unconscio...
# 7663                                                NaN
#
#      Official disposition of death (justified or other) Criminal Charges?  \
# 0                                                   NaN               NaN
# 1                                                   NaN               NaN
# 2                                                   NaN               NaN
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 7659                                          Justified  No known charges
# 7660                                          Justified  No known charges
# 7661                                          Justified  No known charges
# 7662                                         Unreported  No known charges
# 7663                                                NaN               NaN
#
#      Alleged Weapon (Source: WaPo)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 7659                           gun
# 7660                           gun
# 7661                           gun
# 7662                       unarmed
# 7663                           NaN
#
# [8659 rows x 21 columns]

# %%
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8659 entries, 0 to 7663
# Data columns (total 23 columns):
# id                                                                2530 non-null float64
# Victim's name                                                     8658 non-null object
# Date of Incident (month/day/year)                                 8658 non-null object
# Cause of death                                                    8658 non-null object
# Unarmed                                                           8649 non-null object
# Victim's age                                                      8423 non-null float64
# Victim's gender                                                   8651 non-null object
# Victim's race                                                     8467 non-null object
# City                                                              8652 non-null object
# State                                                             8658 non-null object
# Symptoms of mental illness?                                       8647 non-null object
# Alleged Threat Level (Source: WaPo)                               6312 non-null object
# Fleeing (Source: WaPo)                                            6028 non-null object
# Body Camera (Source: WaPo)                                        5833 non-null object
# Street Address of Incident                                        6057 non-null object
# Zipcode                                                           6093 non-null float64
# County                                                            6114 non-null object
# Agency responsible for death                                      6112 non-null object
# A brief description of the circumstances surrounding the death    6109 non-null object
# Official disposition of death (justified or other)                5954 non-null object
# Criminal Charges?                                                 6128 non-null object
# Alleged Weapon (Source: WaPo)                                     6128 non-null object
# ID                                                                6128 non-null float64
# dtypes: float64(4), object(19)
# memory usage: 1.6+ MB
