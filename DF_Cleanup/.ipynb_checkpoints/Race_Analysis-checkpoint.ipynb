# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
DataSet1 = "datasets_2647_4395_PoliceKillingsUS.csv"
DataSet1 = pd.read_csv(DataSet1)
Renamed = DataSet1.rename(columns={"city":"City","state":"State"})
Renamed.count()
# Out:
# id                         2535
# name                       2535
# date                       2535
# manner_of_death            2535
# armed                      2526
# age                        2458
# gender                     2535
# race                       2340
# City                       2535
# State                      2535
# signs_of_mental_illness    2535
# threat_level               2535
# flee                       2470
# body_camera                2535
# dtype: int64

# %%
DataSet2 = "police_killings_new.csv"
DataSet2 = pd.read_csv(DataSet2)
DataSet2.count()
# Out:
# Victim's name             7663
# Victim's age              7596
# Victim's gender           7655
# Victim's race             7663
# URL of image of victim    4200
#                           ...
# Unnamed: 61                  0
# Unnamed: 62                  0
# Unnamed: 63                  0
# Unnamed: 64                  0
# Unnamed: 65                  0
# Length: 66, dtype: int64

# %%
CombinedDataSet = pd.merge(DataSet2, Renamed, how="left", on=["City", "State"])
CombinedDataSet.count()
# Out:
# Victim's name              34536
# Victim's age               34232
# Victim's gender            34533
# Victim's race              34536
# URL of image of victim     17274
#                            ...
# race                       32461
# signs_of_mental_illness    34788
# threat_level               34788
# flee                       33834
# body_camera                34788
# Length: 78, dtype: int64

# %%
Remove_NA = Renamed.dropna(how='all')
Remove_NA
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
# ...

# %%
Victims_race = Remove_NA.groupby(["Victim's race"])
Victims_race = Victims_race.count()
Victims_race_count = Victims_race.rename(columns={"Victim's name": "Victims Count"})
Victims_race_count
# Out:
#                   Victims Count  Victim's age  Victim's gender  \
# Victim's race
# Asian                       613           613              613
# Black                     12081         12068            12080
# Hispanic                  10079          9999            10077
# Native American             402           401              401
# Pacific Islander            124           124              124
# Unknown Race                225           225              225
# Unknown race               2775          2563             2773
# White                     10890         10859            10887
#
#                   URL of image of victim  Date of Incident (month/day/year)  \
# Victim's race
# Asian                                278                                613
# Black                               7227                              12081
# Hispanic                            4140                              10079
# ...

# %%
#create a new DF with count only
