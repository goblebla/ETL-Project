# %%
import pandas as pd

# %%
race = "ShareRaceByCity.csv"
Race = pd.read_csv(race)
Race
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-1f01cd0a2f02> in <module>
#       1 race = "ShareRaceByCity.csv"
# ----> 2 Race = pd.read_csv(race)
#       3 Race
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ShareRaceByCity.csv does not exist: 'ShareRaceByCity.csv'

# %%
poverty = "datasets_2647_4395_PercentagePeopleBelowPovertyLevel.csv"
Poverty = pd.read_csv(poverty)
Poverty

# %%
RacePoverity = pd.merge(Race, Poverty, how="left", left_on=["City", "Geographic area"], right_on=["City", "Geographic Area"])
RacePoverity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-759619e1e417> in <module>
# ----> 1 RacePoverity = pd.merge(Race, Poverty, how="left", left_on=["City", "Geographic area"], right_on=["City", "Geographic Area"])
#       2 RacePoverity
#
# NameError: name 'Race' is not defined

# %%
new = Poverty["City"].str.replace("\scity", "")
Poverty["City"]= new
Poverty
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2c010d665a92> in <module>
# ----> 1 new = Poverty["City"].str.replace("\scity", "")
#       2 Poverty["City"]= new
#       3 Poverty
#
# NameError: name 'Poverty' is not defined

# %%
DataSet1 = "datasets_2647_4395_PoliceKillingsUS.csv"
DataSet1 = pd.read_csv(DataSet1)
Renamed = DataSet1.rename(columns={"city":"City","state":"State","name":"Victim's name",
                                   "age":"Victim's age", "gender":"Victim's gender","race":"Victim's race"})
Renamed
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c188aebe7937> in <module>
#       1 DataSet1 = "datasets_2647_4395_PoliceKillingsUS.csv"
# ----> 2 DataSet1 = pd.read_csv(DataSet1)
#       3 Renamed = DataSet1.rename(columns={"city":"City","state":"State","name":"Victim's name",
#       4                                    "age":"Victim's age", "gender":"Victim's gender","race":"Victim's race"})
#       5 Renamed
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File datasets_2647_4395_PoliceKillingsUS.csv does not exist: 'datasets_2647_4395_PoliceKillingsUS.csv'

# %%
#Renamed = pd.DataFrame({"Victim's name":[len(Renamed["Victim's name"].unique())]})
#Renamed

# %%
DataSet2 = "police_killings_new.csv"
DataSet2 = pd.read_csv(DataSet2)
DataSet2
# Out:
#                 Victim's name Victim's age Victim's gender Victim's race  \
# 0              Eric M. Tellez           28            Male         White
# 1     Name withheld by police          NaN            Male  Unknown race
# 2                Terry Hudson           57            Male         Black
# 3              Malik Williams           23            Male         Black
# 4           Frederick Perkins           37            Male         Black
# ...                       ...          ...             ...           ...
# 7902                      NaN          NaN             NaN           NaN
# 7903                      NaN          NaN             NaN           NaN
# 7904                      NaN          NaN             NaN           NaN
# 7905                      NaN          NaN             NaN           NaN
# 7906                      NaN          NaN             NaN           NaN
#
#                                  URL of image of victim  \
# 0     https://fatalencounters.org/wp-content/uploads...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7902                                                NaN
# 7903                                                NaN
# 7904                                                NaN
# 7905                                                NaN
# 7906                                                NaN
#
#      Date of Incident (month/day/year) Street Address of Incident  \
# 0                           31/12/2019                 Broad St.
# 1                           31/12/2019             7239-7411 I-40
# 2                           31/12/2019             3600 N 24th St
# 3                           31/12/2019    30800 14th Avenue South
# 4                           31/12/2019        17057 N Outer 40 Rd
# ...                                ...                        ...
# 7902                               NaN                        NaN
# 7903                               NaN                        NaN
# 7904                               NaN                        NaN
# 7905                               NaN                        NaN
# 7906                               NaN                        NaN
#
#               City State  Zipcode  ... Unnamed: 56 Unnamed: 57 Unnamed: 58  \
# 0            Globe    AZ  85501.0  ...         NaN         NaN         NaN
# 1          Memphis    AR  38103.0  ...         NaN         NaN         NaN
# 2            Omaha    NE  68110.0  ...         NaN         NaN         NaN
# 3      Federal Way    WA  98003.0  ...         NaN         NaN         NaN
# 4     Chesterfield    MO  63005.0  ...         NaN         NaN         NaN
# ...            ...   ...      ...  ...         ...         ...         ...
# 7902           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7903           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7904           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7905           NaN   NaN      NaN  ...         NaN         NaN         NaN
# 7906           NaN   NaN      NaN  ...         NaN         NaN         NaN
#
#      Unnamed: 59 Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 7902         NaN         NaN         NaN         NaN         NaN         NaN
# 7903         NaN         NaN         NaN         NaN         NaN         NaN
# 7904         NaN         NaN         NaN         NaN         NaN         NaN
# 7905         NaN         NaN         NaN         NaN         NaN         NaN
# 7906         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 65
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7902         NaN
# 7903         NaN
# 7904         NaN
# 7905         NaN
# 7906         NaN
#
# [7907 rows x 66 columns]

# %%
#DataSet2["Victim's age"] = DataSet2["Victim's age"].astype(float)

# %%
DataSet2.head()
Renamed.head()
# Out:
#    id       Victim's name      date   manner_of_death       armed  \
# 0   3          Tim Elliot  02/01/15              shot         gun
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun
#
#    Victim's age Victim's gender Victim's race           City State  \
# 0          53.0               M             A        Shelton    WA
# 1          47.0               M             W          Aloha    OR
# 2          23.0               M             H        Wichita    KS
# 3          32.0               M             W  San Francisco    CA
# 4          39.0               M             H          Evans    CO
#
#    signs_of_mental_illness threat_level         flee  body_camera
# 0                     True       attack  Not fleeing        False
# 1                    False       attack  Not fleeing        False
# 2                    False        other  Not fleeing        False
# 3                     True       attack  Not fleeing        False
# 4                    False       attack  Not fleeing        False

# %%
CombinedDataSet = pd.merge(DataSet2, Renamed, how="outer", left_on=["Victim's name","City", "State"], 
                           right_on=["Victim's name","City", "State"])
CombinedDataSet
# Out:
#                    Victim's name Victim's age_x Victim's gender_x  \
# 0                 Eric M. Tellez             28              Male
# 1        Name withheld by police            NaN              Male
# 2                   Terry Hudson             57              Male
# 3                 Malik Williams             23              Male
# 4              Frederick Perkins             37              Male
# ...                          ...            ...               ...
# 8965                       TK TK            NaN               NaN
# 8966  Jerauld Phillip Hammond II            NaN               NaN
# 8967              Matthew Folden            NaN               NaN
# 8968            Brian J. Skinner            NaN               NaN
# 8969                       TK TK            NaN               NaN
#
#      Victim's race_x                             URL of image of victim  \
# 0              White  https://fatalencounters.org/wp-content/uploads...
# 1       Unknown race                                                NaN
# 2              Black                                                NaN
# 3              Black                                                NaN
# 4              Black                                                NaN
# ...              ...                                                ...
# 8965             NaN                                                NaN
# 8966             NaN                                                NaN
# 8967             NaN                                                NaN
# 8968             NaN                                                NaN
# 8969             NaN                                                NaN
#
#      Date of Incident (month/day/year) Street Address of Incident  \
# 0                           31/12/2019                 Broad St.
# 1                           31/12/2019             7239-7411 I-40
# 2                           31/12/2019             3600 N 24th St
# 3                           31/12/2019    30800 14th Avenue South
# 4                           31/12/2019        17057 N Outer 40 Rd
# ...                                ...                        ...
# 8965                               NaN                        NaN
# 8966                               NaN                        NaN
# 8967                               NaN                        NaN
# 8968                               NaN                        NaN
# 8969                               NaN                        NaN
#
#               City State  Zipcode  ...      date manner_of_death    armed  \
# 0            Globe    AZ  85501.0  ...       NaN             NaN      NaN
# 1          Memphis    AR  38103.0  ...       NaN             NaN      NaN
# 2            Omaha    NE  68110.0  ...       NaN             NaN      NaN
# 3      Federal Way    WA  98003.0  ...       NaN             NaN      NaN
# 4     Chesterfield    MO  63005.0  ...       NaN             NaN      NaN
# ...            ...   ...      ...  ...       ...             ...      ...
# 8965   San Antonio    TX      NaN  ...  26/07/17            shot      gun
# 8966   Los Angeles    CA      NaN  ...  27/07/17            shot      gun
# 8967     Wenatchee    WA      NaN  ...  27/07/17            shot    knife
# 8968     Glenville    NY      NaN  ...  28/07/17            shot    knife
# 8969   Albuquerque    NM      NaN  ...  28/07/17            shot  vehicle
#
#      Victim's age_y Victim's gender_y Victim's race_y signs_of_mental_illness  \
# 0               NaN               NaN             NaN                     NaN
# 1               NaN               NaN             NaN                     NaN
# 2               NaN               NaN             NaN                     NaN
# 3               NaN               NaN             NaN                     NaN
# 4               NaN               NaN             NaN                     NaN
# ...             ...               ...             ...                     ...
# 8965            NaN                 M             NaN                   False
# 8966           46.0                 M             NaN                   False
# 8967           31.0                 M             NaN                   False
# 8968           32.0                 M             NaN                    True
# 8969            NaN                 M             NaN                   False
#
#      threat_level         flee body_camera
# 0             NaN          NaN         NaN
# 1             NaN          NaN         NaN
# 2             NaN          NaN         NaN
# 3             NaN          NaN         NaN
# 4             NaN          NaN         NaN
# ...           ...          ...         ...
# 8965       attack  Not fleeing       False
# 8966        other  Not fleeing       False
# 8967        other  Not fleeing       False
# 8968        other  Not fleeing       False
# 8969       attack          Car       False
#
# [8970 rows x 77 columns]

# %%
CombinedDataSet.columns
# Out:
# Index(['Victim's name', 'Victim's age_x', 'Victim's gender_x',
#        'Victim's race_x', 'URL of image of victim',
#        'Date of Incident (month/day/year)', 'Street Address of Incident',
#        'City', 'State', 'Zipcode', 'County', 'Agency responsible for death',
#        'Cause of death',
#        'A brief description of the circumstances surrounding the death',
#        'Official disposition of death (justified or other)',
#        'Criminal Charges?',
#        'Link to news article or photo of official document',
#        'Symptoms of mental illness?', 'Unarmed',
#        'Alleged Weapon (Source: WaPo)', 'Alleged Threat Level (Source: WaPo)',
#        'Fleeing (Source: WaPo)', 'Body Camera (Source: WaPo)',
#        'WaPo ID (If included in WaPo database)', 'Off-Duty Killing?',
#        'Geography (via Trulia methodology based on zipcode population density: http://jedkolko.com/wp-content/uploads/2015/05/full-ZCTA-urban-suburban-rural-classification.xlsx )',
#        'ID', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46',
#        'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50',
#        'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54',
#        'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58',
#        'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62',
#        'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'id', 'date',
#        'manner_of_death', 'armed', 'Victim's age_y', 'Victim's gender_y',
#        'Victim's race_y', 'signs_of_mental_illness', 'threat_level', 'flee',
#        'body_camera'],
#       dtype='object')

# %%
UniqueNames_df = pd.DataFrame({"Victim's name":[len(CombinedDataSet["Victim's name"].unique())]})
UniqueNames_df
# Out:
#    Victim's name
# 0           8145

# %%
CombinedDataSet = CombinedDataSet[["Victim's Name","Victim's age_x"]]
CombinedDataSet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f0c26be65e5> in <module>
# ----> 1 CombinedDataSet = CombinedDataSet[["Victim's Name","Victim's age_x"]]
#       2 CombinedDataSet
#
# NameError: name 'CombinedDataSet' is not defined
